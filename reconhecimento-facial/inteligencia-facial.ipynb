# %%
import cv2 #opencv
import mediapipe as mp

#inicializar a opencv e o mediapipe
webcam = cv2.VideoCapture(0)
solucao_reconhecimento_rosto = mp.solutions.face_detection
reconhecedor_rostos = solucao_reconhecimento_rosto.FaceDetection()
desenho = mp.solutions.drawing_utils

while True: 
    #Ler as informações da webcam
    verificador, frame = webcam.read()

    if not verificador:
        break
        
    #reconhecer os rostos que tem ali dentro
    lista_rostos = reconhecedor_rostos.process(frame)
    if lista_rostos.detections: 
        for rosto in lista_rostos.detections:
            desenho.draw_detection(frame, rosto) #desenhar os rostos na imagem
    
    cv2.imshow("Rostos na Webcam", frame)
    #quando apertar ESC, parar o loop
    if cv2.waitKey(5) == 27:
        break
webcam.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Augusto\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\augusto\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 1.6 MB/s eta 0:00:25
#    ---------------------------------------- 0.4/38.8 MB 4.8 MB/s eta 0:00:09
#    - -------------------------------------- 1.1/38.8 MB 8.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.6/38.8 MB 15.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.2/38.8 MB 23.9 MB/s eta 0:00:02
#    -------- ------------------------------- 8.5/38.8 MB 31.9 MB/s eta 0:00:01
#    ------------ --------------------------- 12.2/38.8 MB 65.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 15.8/38.8 MB 81.8 MB/s eta 0:00:01
#    ------------------- -------------------- 18.7/38.8 MB 72.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.3/38.8 MB 72.6 MB/s eta 0:00:01
#    -------------------------- ------------- 26.0/38.8 MB 73.1 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.5/38.8 MB 81.8 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.8 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 73.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 73.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 46.7 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.82

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.14-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\augusto\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.28-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.4.28-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib in c:\users\augusto\anaconda3\lib\site-packages (from mediapipe) (3.8.0)
# Requirement already satisfied: numpy in c:\users\augusto\anaconda3\lib\site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.7-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\augusto\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Downloading ml_dtypes-0.4.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum (from jax->mediapipe)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: scipy>=1.9 in c:\users\augusto\anaconda3\lib\site-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\augusto\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\augusto\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\augusto\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp311-cp311-win_amd64.whl (50.8 MB)
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/50.8 MB 4.2 MB/s eta 0:00:13
#    ---------------------------------------- 0.5/50.8 MB 6.4 MB/s eta 0:00:08
#    - -------------------------------------- 2.1/50.8 MB 16.4 MB/s eta 0:00:03
#    --- ------------------------------------ 4.7/50.8 MB 27.5 MB/s eta 0:00:02
#    ------ --------------------------------- 8.6/50.8 MB 39.4 MB/s eta 0:00:02
#    --------- ------------------------------ 12.1/50.8 MB 72.6 MB/s eta 0:00:01
#    ------------ --------------------------- 16.0/50.8 MB 81.8 MB/s eta 0:00:01
#    --------------- ------------------------ 19.9/50.8 MB 81.8 MB/s eta 0:00:01
#    ------------------ --------------------- 23.6/50.8 MB 81.8 MB/s eta 0:00:01
#    --------------------- ------------------ 27.4/50.8 MB 81.8 MB/s eta 0:00:01
#    ------------------------ --------------- 30.8/50.8 MB 81.8 MB/s eta 0:00:01
#    --------------------------- ------------ 34.9/50.8 MB 81.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 37.1/50.8 MB 81.8 MB/s eta 0:00:01
#    ------------------------------- -------- 40.3/50.8 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 44.0/50.8 MB 65.6 MB/s eta 0:00:01
#    ------------------------------------- -- 47.9/50.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 50.8/50.8 MB 43.7 MB/s eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 25.2 MB/s eta 0:00:00
# Downloading sounddevice-0.4.7-py3-none-win_amd64.whl (200 kB)
#    ---------------------------------------- 0.0/200.1 kB ? eta -:--:--
#    --------------------------------------- 200.1/200.1 kB 12.7 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.7 kB ? eta -:--:--
#    ---------------------------------------- 133.7/133.7 kB 8.2 MB/s eta 0:00:00
# Downloading jax-0.4.28-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 62.3 MB/s eta 0:00:00
# Downloading jaxlib-0.4.28-cp311-cp311-win_amd64.whl (51.5 MB)
#    ---------------------------------------- 0.0/51.5 MB ? eta -:--:--
#    -- ------------------------------------- 3.6/51.5 MB 117.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 7.5/51.5 MB 95.8 MB/s eta 0:00:01
#    -------- ------------------------------- 11.3/51.5 MB 81.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 15.1/51.5 MB 81.8 MB/s eta 0:00:01
#    -------------- ------------------------- 19.0/51.5 MB 81.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 22.4/51.5 MB 81.8 MB/s eta 0:00:01
#    -------------------- ------------------- 26.2/51.5 MB 81.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 29.8/51.5 MB 81.8 MB/s eta 0:00:01
#    ------------------------- -------------- 33.2/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 37.1/51.5 MB 81.8 MB/s eta 0:00:01
#    ------------------------------- -------- 40.7/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 44.4/51.5 MB 81.8 MB/s eta 0:00:01
#    ------------------------------------- -- 48.0/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  51.5/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  51.5/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  51.5/51.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 51.5/51.5 MB 40.9 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.82-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.5/45.5 MB 76.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 6.3/45.5 MB 80.2 MB/s eta 0:00:01
#    ------ --------------------------------- 7.5/45.5 MB 53.2 MB/s eta 0:00:01
#    ------- -------------------------------- 8.1/45.5 MB 57.6 MB/s eta 0:00:01
#    ------- -------------------------------- 8.9/45.5 MB 38.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.0/45.5 MB 40.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.9/45.5 MB 93.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 20.1/45.5 MB 81.8 MB/s eta 0:00:01
#    ------------------- -------------------- 22.7/45.5 MB 65.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 26.0/45.5 MB 59.5 MB/s eta 0:00:01
#    -------------------------- ------------- 29.8/45.5 MB 54.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.4/45.5 MB 81.8 MB/s eta 0:00:01
#    -------------------------------- ------- 37.2/45.5 MB 81.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.7/45.5 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.5 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 45.5/45.5 MB 43.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.0-cp311-cp311-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.8 kB ? eta -:--:--
#    ---------------------------------------- 126.8/126.8 kB 7.3 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.5 kB ? eta -:--:--
#    ---------------------------------------- 65.5/65.5 kB ? eta 0:00:00
# Installing collected packages: flatbuffers, protobuf, opt-einsum, opencv-contrib-python, ml-dtypes, absl-py, sounddevice, jaxlib, jax, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed absl-py-2.1.0 flatbuffers-24.3.25 jax-0.4.28 jaxlib-0.4.28 mediapipe-0.10.14 ml-dtypes-0.4.0 opencv-contrib-python-4.10.0.82 opt-einsum-3.3.0 protobuf-4.25.3 sounddevice-0.4.7
